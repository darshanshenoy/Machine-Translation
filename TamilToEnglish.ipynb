# %% [markdown]
# Speech To Text

# %%
# !pip install SpeechRecognition
# !apt install libasound2-dev portaudio19-dev libportaudio2 libportaudiocpp0 ffmpeg
# !pip install PyAudio
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting SpeechRecognition
#   Downloading SpeechRecognition-3.9.0-py2.py3-none-any.whl (32.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 32.8/32.8 MB 18.1 MB/s eta 0:00:00
# Collecting requests>=2.26.0
#   Downloading requests-2.28.2-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.8/62.8 KB 4.0 MB/s eta 0:00:00
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests>=2.26.0->SpeechRecognition) (2022.12.7)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.8/dist-packages (from requests>=2.26.0->SpeechRecognition) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests>=2.26.0->SpeechRecognition) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests>=2.26.0->SpeechRecognition) (1.24.3)
# Installing collected packages: requests, SpeechRecognition
#   Attempting uninstall: requests
#     Found existing installation: requests 2.25.1
#     Uninstalling requests-2.25.1:
#       Successfully uninstalled requests-2.25.1
# Successfully installed SpeechRecognition-3.9.0 requests-2.28.2
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# libasound2-dev is already the newest version (1.2.2-2.1ubuntu2.5).
# ffmpeg is already the newest version (7:4.2.7-0ubuntu0.1).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-510
# Use 'apt autoremove' to remove it.
# Suggested packages:
#   portaudio19-doc
# The following NEW packages will be installed:
#   libportaudio2 libportaudiocpp0 portaudio19-dev
# 0 upgraded, 3 newly installed, 0 to remove and 21 not upgraded.
# Need to get 188 kB of archives.
# After this operation, 926 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu focal/universe amd64 libportaudio2 amd64 19.6.0-1build1 [65.4 kB]
# Get:2 http://archive.ubuntu.com/ubuntu focal/universe amd64 libportaudiocpp0 amd64 19.6.0-1build1 [16.1 kB]
# Get:3 http://archive.ubuntu.com/ubuntu focal/universe amd64 portaudio19-dev amd64 19.6.0-1build1 [106 kB]
# Fetched 188 kB in 1s (340 kB/s)
# Selecting previously unselected package libportaudio2:amd64.
# (Reading database ... 128097 files and directories currently installed.)
# Preparing to unpack .../libportaudio2_19.6.0-1build1_amd64.deb ...
# Unpacking libportaudio2:amd64 (19.6.0-1build1) ...
# Selecting previously unselected package libportaudiocpp0:amd64.
# Preparing to unpack .../libportaudiocpp0_19.6.0-1build1_amd64.deb ...
# Unpacking libportaudiocpp0:amd64 (19.6.0-1build1) ...
# Selecting previously unselected package portaudio19-dev:amd64.
# Preparing to unpack .../portaudio19-dev_19.6.0-1build1_amd64.deb ...
# Unpacking portaudio19-dev:amd64 (19.6.0-1build1) ...
# Setting up libportaudio2:amd64 (19.6.0-1build1) ...
# Setting up libportaudiocpp0:amd64 (19.6.0-1build1) ...
# Setting up portaudio19-dev:amd64 (19.6.0-1build1) ...
# Processing triggers for libc-bin (2.31-0ubuntu9.9) ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting PyAudio
#   Downloading PyAudio-0.2.13.tar.gz (46 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.8/46.8 KB 5.5 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Building wheels for collected packages: PyAudio
#   Building wheel for PyAudio (pyproject.toml) ... done
#   Created wheel for PyAudio: filename=PyAudio-0.2.13-cp38-cp38-linux_x86_64.whl size=69705 sha256=9d18eb77d0cbfc69063b1fbfd8154ca2210d0c7d865948a1ca68f6712cb430fb
#   Stored in directory: /root/.cache/pip/wheels/c9/64/0b/9a483698792349f565ecc45c5ee3f1efb2ce79464f6d9daf53
# Successfully built PyAudio
# Installing collected packages: PyAudio
# Successfully installed PyAudio-0.2.13

# %%
import speech_recognition as sr
import sys

#filename = sys.argv[1]
filename = "Tamil_Audio.wav"
# initialize the recognizer
r = sr.Recognizer()

# %%
# open the file
with sr.AudioFile(filename) as source:
    # listen for the data (load audio to memory)
    audio_data = r.record(source)
    # recognize (convert from speech to text)
    text = r.recognize_google(audio_data, language='ta-IN')
    #text = r.recognize_google(audio_data)
    print(text)
# Out:
# result2:
# {   'alternative': [   {   'confidence': 0.8870433,
#                            'transcript': 'இரண்டாயிரத்து ஐந்நூறு ஆண்டுகளுக்கும் '
#                                          'மேல் பழமை வாய்ந்த இலக்கிய மரபைக் '
#                                          'கொண்டுள்ள தமிழ் மொழி தற்போது '
#                                          'வழக்கில் இருக்கும் ஒரு சில '
#                                          'செம்மொழிகளில் இதுவும் ஒன்றாகும்'},
#                        {   'transcript': 'இரண்டாயிரத்து ஐந்நூறு ஆண்டுகளுக்கும் '
#                                          'மேல் பழைமை வாய்ந்த இலக்கிய மரபைக் '
#                                          'கொண்டுள்ள தமிழ் மொழி தற்போது '
#                                          'வழக்கில் இருக்கும் ஒரு சில '
#                                          'செம்மொழிகளில் இதுவும் ஒன்றாகும்'},
#                        {   'transcript': '2500 ஆண்டுகளுக்கும் மேல் பழமை '
#                                          'வாய்ந்த இலக்கிய மரபைக் கொண்டுள்ள '
#                                          'தமிழ் மொழி தற்போது வழக்கில் '
#                                          'இருக்கும் ஒரு சில செம்மொழிகளில் '
#                                          'இதுவும் ஒன்றாகும்'},
#                        {   'transcript': '2500 ஆண்டுகளுக்கு மேல் பழமை வாய்ந்த '
#                                          'இலக்கிய மரபைக் கொண்டுள்ள தமிழ் மொழி '
#                                          'தற்போது வழக்கில் இருக்கும் ஒரு சில '
#                                          'செம்மொழிகளில் இதுவும் ஒன்றாகும்'},
#                        {   'transcript': 'இரண்டாயிரத்து ஐந்நூறு ஆண்டுகளுக்கும் '
#                                          'மேல் பழமை வாய்ந்த இலக்கிய மரபைக் '
#                                          'கொண்டுள்ள தமிழ் மொழி தற்போது '
#                                          'வழக்கில் இருக்கும் ஒரு சில '
#                                          'செம்மொழிகளில் இதுவும் ஓன்றாகும்'}],
#     'final': True}
# இரண்டாயிரத்து ஐந்நூறு ஆண்டுகளுக்கும் மேல் பழமை வாய்ந்த இலக்கிய மரபைக் கொண்டுள்ள தமிழ் மொழி தற்போது வழக்கில் இருக்கும் ஒரு சில செம்மொழிகளில் இதுவும் ஒன்றாகும்

# %% [markdown]
# Text Translation

# %%
# !pip3 install googletrans==3.1.0a0
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting googletrans==3.1.0a0
#   Downloading googletrans-3.1.0a0.tar.gz (19 kB)
# Collecting httpx==0.13.3
#   Downloading httpx-0.13.3-py3-none-any.whl (55 kB)
#      |████████████████████████████████| 55 kB 2.2 MB/s
# Collecting hstspreload
#   Downloading hstspreload-2022.12.1-py3-none-any.whl (1.5 MB)
#      |████████████████████████████████| 1.5 MB 11.5 MB/s
# Collecting httpcore==0.9.*
#   Downloading httpcore-0.9.1-py3-none-any.whl (42 kB)
#      |████████████████████████████████| 42 kB 1.2 MB/s
# Requirement already satisfied: certifi in /usr/local/lib/python3.8/dist-packages (from httpx==0.13.3->googletrans==3.1.0a0) (2022.9.24)
# Collecting rfc3986<2,>=1.3
#   Downloading rfc3986-1.5.0-py2.py3-none-any.whl (31 kB)
# Collecting sniffio
#   Downloading sniffio-1.3.0-py3-none-any.whl (10 kB)
# Requirement already satisfied: chardet==3.* in /usr/local/lib/python3.8/dist-packages (from httpx==0.13.3->googletrans==3.1.0a0) (3.0.4)
# Requirement already satisfied: idna==2.* in /usr/local/lib/python3.8/dist-packages (from httpx==0.13.3->googletrans==3.1.0a0) (2.10)
# Collecting h11<0.10,>=0.8
#   Downloading h11-0.9.0-py2.py3-none-any.whl (53 kB)
#      |████████████████████████████████| 53 kB 1.9 MB/s
# Collecting h2==3.*
#   Downloading h2-3.2.0-py2.py3-none-any.whl (65 kB)
#      |████████████████████████████████| 65 kB 3.0 MB/s
# Collecting hyperframe<6,>=5.2.0
#   Downloading hyperframe-5.2.0-py2.py3-none-any.whl (12 kB)
# Collecting hpack<4,>=3.0
#   Downloading hpack-3.0.0-py2.py3-none-any.whl (38 kB)
# Building wheels for collected packages: googletrans
#   Building wheel for googletrans (setup.py) ... done
#   Created wheel for googletrans: filename=googletrans-3.1.0a0-py3-none-any.whl size=16368 sha256=a7c8d0ce1b7e3802a4dd4ce11c82bacf2493611d86b60cfd20dd382863b45669
#   Stored in directory: /root/.cache/pip/wheels/dd/59/af/8d6c96a719763990f1c548e36b17d9efdfb767f42f7ff39f53
# Successfully built googletrans
# Installing collected packages: hyperframe, hpack, sniffio, h2, h11, rfc3986, httpcore, hstspreload, httpx, googletrans
# Successfully installed googletrans-3.1.0a0 h11-0.9.0 h2-3.2.0 hpack-3.0.0 hstspreload-2022.12.1 httpcore-0.9.1 httpx-0.13.3 hyperframe-5.2.0 rfc3986-1.5.0 sniffio-1.3.0

# %%
from googletrans import Translator
translator = Translator()

# %%
translations = translator.translate(text, dest='en')  
print(translations.origin, ' -> ', translations.text)
# Out:
# இரண்டாயிரத்து ஐந்நூறு ஆண்டுகளுக்கும் மேல் பழமை வாய்ந்த இலக்கிய மரபைக் கொண்டுள்ள தமிழ் மொழி தற்போது வழக்கில் இருக்கும் ஒரு சில செம்மொழிகளில் இதுவும் ஒன்றாகும்  ->  Tamil is one of the few surviving classical languages ​​with a literary tradition of more than two thousand five hundred years.

# %% [markdown]
# Text to Speech

# %%
# !pip install gTTS
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting gTTS
#   Downloading gTTS-2.3.0-py3-none-any.whl (26 kB)
# Requirement already satisfied: requests~=2.28.0 in /usr/local/lib/python3.8/dist-packages (from gTTS) (2.28.1)
# Collecting click~=8.1.3
#   Downloading click-8.1.3-py3-none-any.whl (96 kB)
#      |████████████████████████████████| 96 kB 3.3 MB/s
# Collecting six~=1.16.0
#   Downloading six-1.16.0-py2.py3-none-any.whl (11 kB)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.8/dist-packages (from requests~=2.28.0->gTTS) (1.24.3)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.8/dist-packages (from requests~=2.28.0->gTTS) (2.10)
# Requirement already satisfied: charset-normalizer<3,>=2 in /usr/local/lib/python3.8/dist-packages (from requests~=2.28.0->gTTS) (2.1.1)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.8/dist-packages (from requests~=2.28.0->gTTS) (2022.9.24)
# Installing collected packages: six, click, gTTS
#   Attempting uninstall: six
#     Found existing installation: six 1.15.0
#     Uninstalling six-1.15.0:
#       Successfully uninstalled six-1.15.0
#   Attempting uninstall: click
#     Found existing installation: click 7.1.2
#     Uninstalling click-7.1.2:
#       Successfully uninstalled click-7.1.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ipython 7.9.0 requires jedi>=0.10, which is not installed.
# flask 1.1.4 requires click<8.0,>=5.1, but you have click 8.1.3 which is incompatible.
# Successfully installed click-8.1.3 gTTS-2.3.0 six-1.16.0

# %%
from gtts import gTTS
#import IPython
#from IPython import display
from IPython.display import Audio
tts = gTTS(translations.text, lang='en')
tts.save('2.wav')
sound_file = '2.wav'
Audio(sound_file, autoplay=True)
# Out:
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
